# %%
from huggingface_hub import HfApi, create_repo, upload_folder

# Ensure repo exists locally
repo_id = "TahaBa/phi3-mini-general-adapters"
create_repo(repo_id=repo_id, repo_type="model", exist_ok=True)

# Upload your entire local directory
upload_folder(
    folder_path="/home/dev/persian-llm/le_experts_phi3_diff_lang/le_experts_phi3_diff_lang",
    repo_id=repo_id,
    repo_type="model",
    ignore_patterns="**/.git/**",   # ignore any .git if present
)
# Out:
# adapter_model.safetensors:   0%|          | 0.00/9.45M [00:00<?, ?B/s]
#
#
#
#
#
#
#
#
#
#
#
# adapter_model.safetensors:   0%|          | 16.4k/9.45M [00:00<02:23, 65.8kB/s]
#
#
#
# scheduler.pt: 100%|██████████| 1.06k/1.06k [00:01<00:00, 976B/s]  01, 6.11MB/s]
# rng_state.pth: 100%|██████████| 14.2k/14.2k [00:01<00:00, 13.1kB/s]
# training_args.bin: 100%|██████████| 5.62k/5.62k [00:01<00:00, 5.08kB/s]
# adapter_model.safetensors:  84%|████████▍ | 7.96M/9.45M [00:01<00:00, 7.62MB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# optimizer.pt: 100%|██████████| 4.94M/4.94M [00:02<00:00, 2.02MB/s]
#
#
#
# adapter_model.safetensors: 100%|██████████| 9.45M/9.45M [00:02<00:00, 3.65MB/s]
#
#
#
# scheduler.pt:   0%|          | 0.00/1.06k [00:00<?, ?B/s]
# rng_state.pth: 100%|██████████| 14.2k/14.2k [00:00<00:00, 15.9kB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# training_args.bin: 100%|██████████| 5.62k/5.62k [00:00<00:00, 15.9kB/s]
#
#
#
#
#
#
# ...

# %%
# from huggingface_hub import HfApi

# api = HfApi()
# repo_id = "TahaBa/phi3-mini-clustered-flan"

# for name in [f"cluster{i}" for i in range(10)]:
#     path = name + "/"  # ensure trailing slash
#     api.delete_folder(repo_id=repo_id, path_in_repo=path, repo_type="model")
